# %% [markdown]
# # Welcome to Jupyter!

# %%
# !pip install durable-rules
# Out:
# ...
#      |████████████████████████████████| 57 kB 3.0 MB/s eta 0:00:011
# ...
#   Created wheel for durable-rules: filename=durable_rules-2.0.28-cp36-cp36m-linux_x86_64.whl size=204018 sha256=2f8c1df0b91da5927c19d5081553580d5f6d8170e133e7a6c8862988e22c6665
#   Stored in directory: /home/jovyan/.cache/pip/wheels/fe/9c/63/444874f34ca8d8c9d99097d6359c1c49a65c20b6361bf6e1b4
# Successfully built durable-rules
# ...

# %%
from durable.lang import *

# %%
print('************************Artificial Intelligence****************************')
print('***********Course and Extra Curricular Activity Suggestion System**********')
print('************************Drishya Uniyal*************************************')
print('************************MT21119********************************************')


#input the required details
name = input('What is your name?\n')
print ('Hi, %s.' % name)

grade = input('What is your grade?\n')
print('%s.' %grade)

#suggesting a student according to the grade what he/she must select
if grade == 'A':  
    print('Select from the following your interested area')
    print('conversation-Based Courses ')
    print('interaction-Based Courses\n')

    interested_area = input('Enter your interests\n')

    print('Select from the following your interested type of course')
    print('Theory ')
    print('NoTheory')
    print('Practicals\n')

    interested_type = input('Enter your interests\n')

    print('Select your Extra Curricular Activity you would like to do')
    print('Sports')
    print('Community Service')
    print('Hobbies')
    print('Leadership')

    activity = input('Enter your interested activity\n')
    with ruleset('interests'):
        # will be triggered by 'interests' facts
        @when_all((m.area == 'conversation-based') & (m.type == 'notheory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'graph' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })

        @when_all((m.area == 'conversation-based') & (m.type == 'notheory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })


        @when_all((m.area == 'conversation-based') & (m.type == 'notheory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'discrete' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'networks' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'cntheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'software' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })
            c.assert_fact('preferences', { 'type': 'setheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'cloud' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Big Data Analytics' })
            c.assert_fact('preferences', { 'type': 'nlptheory' })
                        
        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Big Data Analytics' })
            c.assert_fact('preferences', { 'type': 'mltheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Big Data Analytics' })
            c.assert_fact('preferences', { 'type': 'dltheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical'))
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'languages' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'language' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'database' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'dbtheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'azure' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'notheory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'logic' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })

        @when_all((m.area == 'interaction-based') & (m.type == 'theory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })
            c.assert_fact('preferences', { 'type': 'mltheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'notheory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })

        @when_all((m.area == 'interaction-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'natural language processing' })
            c.assert_fact('preferences', { 'type': 'nlptheory' })

        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object))


    with ruleset('new_skills'):

        @when_all((m.field == 'languages'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take C Language' })
            d.assert_fact({ 'subject': 'take C++ Language' })
            d.assert_fact({ 'subject': 'take Java Language' })
            d.assert_fact({ 'subject': 'take Python Language' })

        @when_all((m.field == 'graph'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Design Graph course' })

            
        @when_all((m.field == 'discrete'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Discrete Mathematics Course' })
            
        @when_all((m.field == 'database'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take DataBase Management Systems' })

        @when_all((m.field == 'probability'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Statistical Probability' })

        @when_all((m.field == 'logic'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Logic Design course' })

        @when_all((m.field == 'azure'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AWS Course' })

        @when_all((m.field == 'networks'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Computer Networks' })

        @when_all((m.field == 'software'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Software Engineering' })

        @when_all((m.field == 'ai-ml'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AI course' })
            d.assert_fact({ 'subject': 'take ML course' })
            d.assert_fact( {'subject': 'take DL course' })

        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))
            

    with ruleset('preferences'):
        @when_all((m.type == 'mltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Machine Learning theory course'})

        @when_all((m.type == 'nlptheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take NLP foundations course'})

        @when_all((m.type == 'dltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take DL theory course'})

        @when_all((m.type == 'cntheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Take Computer Networks '})

        @when_all((m.type == 'setheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Software Engineering course'})

        @when_all((m.type == 'cloudtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Cloud Computing Foundation Course'})

        @when_all((m.type == 'language'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take a language subject in alternate semesters'})

        @when_all((m.type == 'dbtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Take DataBase Management System'})


        @when_all(+m.subject)
        def output(c):
            print('Fact: {0}'.format(c.m.subject))




    with ruleset('activities'):
        # will be triggered by 'interests' facts
        @when_all(m.activity == 'Sports')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Sports' })
            c.assert_fact({ 'sport': 'choose', 'object': 'Cricket' })

        @when_all(m.activity == 'Community Service')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Community Servive' })
            c.assert_fact({ 'subject': 'choose','object': 'Community Service' })


        @when_all(m.activity == 'Hobbies') 
        def hci(c):
            c.assert_fact('skills', { 'field': 'Hobbies' })
            c.assert_fact({ 'subject': 'choose','object': 'Hobbies' })

        @when_all(m.activity == 'Leadership')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Leadership' })
            c.assert_fact({ 'subject': 'choose','object': 'Leaderships' })       



        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} '.format(c.m.subject,c.m.object))




    with ruleset('skills'):

        @when_all((m.field == 'Sports'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Cricket Club' })
            d.assert_fact({ 'subject': 'Join Badminton Club' })
            d.assert_fact({ 'subject': 'Join Tennis Club' })
            d.assert_fact({ 'subject': 'Join VolleyBall Club' })

        @when_all((m.field == 'Community Service'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join NSA Group' })

        @when_all((m.field == 'Hobbies'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Dance Club' })
            d.assert_fact({ 'subject': 'Join Singing Club' })
            d.assert_fact({ 'subject': 'Join Acting Club' })
            d.assert_fact({ 'subject': 'Join Debate Club' })

        @when_all((m.field == 'Leadership'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Leader Training Camp Club' })


        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))
            
            
elif grade == 'B':
    print('Select from the following your interested area')
    print('conversation-Based Courses ')
    print('interaction-Based Courses\n')

    interested_area = input('Enter your interests\n')

    print('Select from the following your interested type of course')
    print('Theory ')
    print('NoTheory')
    print('Practicals\n')

    interested_type = input('Enter your interests\n')

    print('Select your Extra Curricular Activity you would like to do')
    print('Sports')
    print('Community Service')
    print('Hobbies')
    print('Leadership\n')

    activity = input('Enter your interested activity\n')
    with ruleset('interests'):
        @when_all((m.area == 'conversation-based') & (m.type == 'notheory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'discrete' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'networks' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'cntheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'software' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })
            c.assert_fact('preferences', { 'type': 'setheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'cloud' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'database' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'dbtheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'azure' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'notheory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'logic' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })

        @when_all((m.area == 'interaction-based') & (m.type == 'theory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })
            c.assert_fact('preferences', { 'type': 'mltheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'notheory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })

        @when_all((m.area == 'interaction-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'natural language processing' })
            c.assert_fact('preferences', { 'type': 'nlptheory' })

        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object))


    with ruleset('new_skills'):


        @when_all((m.field == 'languages'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take C Language' })
            d.assert_fact({ 'subject': 'take C++ Language' })
            d.assert_fact({ 'subject': 'take Java Language' })
            d.assert_fact({ 'subject': 'take Python Language' })

        @when_all((m.field == 'database'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take DataBase Management Systems' })

        @when_all((m.field == 'probability'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Statistical Probability' })

        @when_all((m.field == 'logic'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Logic Design course' })

        @when_all((m.field == 'azure'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AWS Course' })

        @when_all((m.field == 'networks'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Computer Networks' })

        @when_all((m.field == 'software'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Software Engineering' })

        @when_all((m.field == 'ai-ml'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AI course' })
            d.assert_fact({ 'subject': 'take ML course' })
            d.assert_fact( {'subject': 'take DL course' })

        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))

    with ruleset('preferences'):
        @when_all((m.type == 'mltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Machine Learning theory course'})

        @when_all((m.type == 'nlptheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take NLP foundations course'})

        @when_all((m.type == 'dltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take DL theory course'})

        @when_all((m.type == 'cntheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Necessary Subject for all electives'})

        @when_all((m.type == 'setheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Software Engineering course'})

        @when_all((m.type == 'cloudtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Cloud Computing Foundation Course'})

        @when_all((m.type == 'language'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take a language subject in alternate semesters'})

        @when_all((m.type == 'dbtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Take DBMS'})


        @when_all(+m.subject)
        def output(c):
            print('Fact: {0}'.format(c.m.subject))


    with ruleset('activities'):
        # will be triggered by 'interests' facts
        @when_all(m.activity == 'Sports')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Sports' })
            c.assert_fact({ 'sport': 'choose', 'object': 'Cricket' })

        @when_all(m.activity == 'Community Service')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Community Servive' })
            c.assert_fact({ 'subject': 'choose','object': 'Community Service' })


        @when_all(m.activity == 'Hobbies') 
        def hci(c):
            c.assert_fact('skills', { 'field': 'Hobbies' })
            c.assert_fact({ 'subject': 'choose','object': 'Hobbies' })

        @when_all(m.activity == 'Leadership')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Leadership' })
            c.assert_fact({ 'subject': 'choose','object': 'Leaderships' })       



        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} '.format(c.m.subject,c.m.object))


    with ruleset('skills'):

        @when_all((m.field == 'Sports'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Cricket Club' })
            d.assert_fact({ 'subject': 'Join Badminton Club' })
            d.assert_fact({ 'subject': 'Join Tennis Club' })
            d.assert_fact({ 'subject': 'Join VolleyBall Club' })

        @when_all((m.field == 'Community Service'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join NSA Group' })

        @when_all((m.field == 'Hobbies'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Dance Club' })
            d.assert_fact({ 'subject': 'Join Singing Club' })
            d.assert_fact({ 'subject': 'Join Acting Club' })
            d.assert_fact({ 'subject': 'Join Debate Club' })

        @when_all((m.field == 'Leadership'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Leader Training Camp Club' })


        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))
    
        
elif grade == 'C':
    print('Select from the following your interested area')
    print('conversation-Based Courses ')
    print('interaction-Based Courses\n')

    interested_area = input('Enter your interests\n')

    print('Select from the following your interested type of course')
    print('Theory ')
    print('Practicals\n')

    interested_type = input('Enter your interests\n')

    print('Select your Extra Curricular Activity you would like to do')
    print('Sports')
    print('Community Service')
    print('Hobbies')
    print('Leadership\n')

    activity = input('Enter your interested activity\n')
    with ruleset('interests'):
        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'networks' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'cntheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'software' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })
            c.assert_fact('preferences', { 'type': 'setheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'cloud' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'database' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'dbtheory' })
            
        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'languages' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'language' })

        @when_all((m.area == 'conversation-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'azure' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })


        @when_all((m.area == 'interaction-based') & (m.type == 'theory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })
            c.assert_fact('preferences', { 'type': 'mltheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'practical') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'probability' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'natural language processing' })
            c.assert_fact('preferences', { 'type': 'nlptheory' })

        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object))


    with ruleset('new_skills'):

        @when_all((m.field == 'languages'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take C Language' })
            d.assert_fact({ 'subject': 'take C++ Language' })
            d.assert_fact({ 'subject': 'take Java Language' })
            d.assert_fact({ 'subject': 'take Python Language' })

        @when_all((m.field == 'database'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take DataBase Management Systems' })

        @when_all((m.field == 'probability'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Statistical Probability' })

        @when_all((m.field == 'logic'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Logic Design course' })

        @when_all((m.field == 'azure'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AWS Course' })

        @when_all((m.field == 'networks'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Computer Networks' })

        @when_all((m.field == 'software'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Software Engineering' })

        @when_all((m.field == 'ai-ml'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AI course' })
            d.assert_fact({ 'subject': 'take ML course' })
            d.assert_fact( {'subject': 'take DL course' })

        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))

    with ruleset('preferences'):
        @when_all((m.type == 'mltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Machine Learning theory course'})

        @when_all((m.type == 'nlptheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take NLP foundations course'})

        @when_all((m.type == 'dltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take DL theory course'})

        @when_all((m.type == 'cntheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Take Computer Networks '})

        @when_all((m.type == 'setheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Software Engineering course'})

        @when_all((m.type == 'cloudtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Cloud Computing Foundation Course'})

        @when_all((m.type == 'language'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take a language subject in alternate semesters'})

        @when_all((m.type == 'dbtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take DBMS'})


        @when_all(+m.subject)
        def output(c):
            print('Fact: {0}'.format(c.m.subject))




    with ruleset('activities'):
        # will be triggered by 'interests' facts
        @when_all(m.activity == 'Sports')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Sports' })
            c.assert_fact({ 'sport': 'choose', 'object': 'Cricket' })

        @when_all(m.activity == 'Community Service')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Community Servive' })
            c.assert_fact({ 'subject': 'choose','object': 'Community Service' })


        @when_all(m.activity == 'Hobbies') 
        def hci(c):
            c.assert_fact('skills', { 'field': 'Hobbies' })
            c.assert_fact({ 'subject': 'choose','object': 'Hobbies' })

        @when_all(m.activity == 'Leadership')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Leadership' })
            c.assert_fact({ 'subject': 'choose','object': 'Leaderships' })       



        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} '.format(c.m.subject,c.m.object))




    with ruleset('skills'):

        @when_all((m.field == 'Sports'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Cricket Club' })
            d.assert_fact({ 'subject': 'Join Badminton Club' })
            d.assert_fact({ 'subject': 'Join Tennis Club' })
            d.assert_fact({ 'subject': 'Join VolleyBall Club' })

        @when_all((m.field == 'Community Service'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join NSA Group' })

        @when_all((m.field == 'Hobbies'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Dance Club' })
            d.assert_fact({ 'subject': 'Join Singing Club' })
            d.assert_fact({ 'subject': 'Join Acting Club' })
            d.assert_fact({ 'subject': 'Join Debate Club' })

        @when_all((m.field == 'Leadership'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Leader Training Camp Club' })


        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))
            
            
            
else :
    print('Select from the following your interested area')
    print('Conversation-Based Courses ')
    print('Interaction-Based Courses\n')

    interested_area = input('Enter your interests\n')
    interested_type = 'theory'

    print('Select your Extra Curricular Activity you would like to do')
    print('Sports')
    print('Community Service')
    print('Hobbies')
    print('Leadership\n')

    activity = input('Enter your interested activity\n')
    with ruleset('interests'):
        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )       
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'languages' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'language' })
        def hci(c):
            print('Necessary Subject for all electives')
            c.assert_fact('new_skills', { 'field': 'networks' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'For All Electives' })
            c.assert_fact('preferences', { 'type': 'cntheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'software' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Data Science' })
            c.assert_fact('preferences', { 'type': 'setheory' })

        @when_all((m.area == 'conversation-based') & (m.type == 'theory') )
        def hci(c):
            c.assert_fact('new_skills', { 'field': 'cloud' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Cloud Computing' })
            c.assert_fact('preferences', { 'type': 'cloudtheory' })

        @when_all((m.area == 'interaction-based') & (m.type == 'theory') )
        def rob(c):
            c.assert_fact('new_skills', { 'field': 'ai-ml' })
            c.assert_fact({ 'subject': 'choose', 'predicate': 'elective', 'object': 'Robotics' })
            c.assert_fact('preferences', { 'type': 'mltheory' })

        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object))


    with ruleset('new_skills'):

        @when_all((m.field == 'languages'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take C Language Beginner Course' })

        @when_all((m.field == 'database'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take DataBase Management Systems' })

        @when_all((m.field == 'probability'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Statistical Probability' })

        @when_all((m.field == 'logic'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Logic Design course' })

        @when_all((m.field == 'azure'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AWS Course' })

        @when_all((m.field == 'networks'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Computer Networks' })

        @when_all((m.field == 'software'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take Software Engineering' })

        @when_all((m.field == 'ai-ml'))
        def mathc(d):
            d.assert_fact({ 'subject': 'take AI course' })
            d.assert_fact({ 'subject': 'take ML course' })
            d.assert_fact( {'subject': 'take DL course' })

        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))

    with ruleset('preferences'):
        @when_all((m.type == 'mltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Machine Learning theory course'})

        @when_all((m.type == 'nlptheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take NLP foundations course'})

        @when_all((m.type == 'dltheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take DL theory course'})

        @when_all((m.type == 'cntheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take computer networks'})

        @when_all((m.type == 'setheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Software Engineering course'})

        @when_all((m.type == 'cloudtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take Cloud Computing Foundation Course'})

        @when_all((m.type == 'language'))
        def mathct(e):
            e.assert_fact({ 'subject': 'take a language subject in alternate semesters'})

        @when_all((m.type == 'dbtheory'))
        def mathct(e):
            e.assert_fact({ 'subject': 'Take database management systems'})


        @when_all(+m.subject)
        def output(c):
            print('Fact: {0}'.format(c.m.subject))




    with ruleset('activities'):
        # will be triggered by 'interests' facts
        @when_all(m.activity == 'Sports')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Sports' })
            c.assert_fact({ 'sport': 'choose', 'object': 'Cricket' })

        @when_all(m.activity == 'Community Service')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Community Service' })
            c.assert_fact({ 'subject': 'choose','object': 'Community Service' })


        @when_all(m.activity == 'Hobbies') 
        def hci(c):
            c.assert_fact('skills', { 'field': 'Hobbies' })
            c.assert_fact({ 'subject': 'choose','object': 'Hobbies' })

        @when_all(m.activity == 'Leadership')
        def hci(c):
            c.assert_fact('skills', { 'field': 'Leadership' })
            c.assert_fact({ 'subject': 'choose','object': 'Leaderships' })       



        @when_all(+m.subject)
        def output(c):
            print('Fact: {0} {1} '.format(c.m.subject,c.m.object))



    with ruleset('skills'):

        @when_all((m.field == 'Sports'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Cricket Club' })
            d.assert_fact({ 'subject': 'Join Badminton Club' })
            d.assert_fact({ 'subject': 'Join Tennis Club' })
            d.assert_fact({ 'subject': 'Join VolleyBall Club' })

        @when_all((m.field == 'Community Service'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join NSA Group' })

        @when_all((m.field == 'Hobbies'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Dance Club' })
            d.assert_fact({ 'subject': 'Join Singing Club' })
            d.assert_fact({ 'subject': 'Join Acting Club' })
            d.assert_fact({ 'subject': 'Join Debate Club' })

        @when_all((m.field == 'Leadership'))
        def mathc(d):
            d.assert_fact({ 'subject': 'Join Leader Training Camp Club' })


        @when_all(+m.subject)
        def output(d):
            print('Fact: {0}'.format(d.m.subject))
    
    
      



assert_fact('interests', { 'area': interested_area, 'type': interested_type })
assert_fact('activities', { 'activity' : activity })
# Out:
# ************************Artificial Intelligence****************************
# ***********Course and Extra Curricular Activity Suggestion System**********
# ************************Drishya Uniyal*************************************
# ************************MT21119********************************************
# What is your name?
# Kim
# Hi, Kim.
# What is your grade?
# D
# D.
# Select from the following your interested area
# Conversation-Based Courses
# Interaction-Based Courses
#
# Enter your interests
# interaction-based
# Select your Extra Curricular Activity you would like to do
# Sports
# Community Service
# Hobbies
# Leadership
#
# Enter your interested activity
# Community Service
# Fact: take DL course
# Fact: take ML course
# Fact: take AI course
# Fact: take Machine Learning theory course
# Fact: choose elective Robotics
# Fact: Join NSA Group
# Fact: choose Community Service
# {'sid': '0', 'id': 'sid-0', '$s': 1}
